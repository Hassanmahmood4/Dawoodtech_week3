# %% [markdown]
# # Week 3 ML Prediction System
#
# This notebook documents the full machine learning workflow for the internship task. It covers dataset loading, preprocessing, model training, evaluation, visualization, and saved model artifacts for a regression task and a classification task.

# %% [markdown]
# ## Project Goals
#
# - Train one regression model and one classification model.
# - Handle preprocessing through reusable scikit-learn pipelines.
# - Evaluate models with appropriate metrics.
# - Save trained models for the Streamlit prediction app.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebook" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src.data_preparation import prepare_all_datasets
from src.train_models import train_all_models

# %% [markdown]
# ## Dataset Preparation
#
# The regression dataset is the diabetes progression dataset. The classification dataset is the breast cancer Wisconsin dataset. Both are provided by scikit-learn and exported into the `data/` folder for reproducible project submission.

# %%
regression_df, classification_df = prepare_all_datasets()
regression_df.head()

# %%
classification_df.head()

# %% [markdown]
# ## Model Training and Evaluation
#
# The training script compares linear models with random forest models. Numeric preprocessing is kept inside pipelines to avoid data leakage.

# %%
metadata = train_all_models()
metadata

# %% [markdown]
# ## Metrics
#
# Regression uses MAE, MSE, RMSE, and R-squared. Classification uses accuracy, precision, recall, and a confusion matrix.

# %%
pd.read_csv(PROJECT_ROOT / "reports" / "regression_metrics.csv")

# %%
pd.read_csv(PROJECT_ROOT / "reports" / "classification_metrics.csv")

# %% [markdown]
# ## Next Step
#
# Run the Streamlit app from the project root:
#
# ```bash
# streamlit run app.py
# ```
